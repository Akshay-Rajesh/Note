# %% [markdown]
# <a href="https://colab.research.google.com/github/Akshay-Rajesh/Note/blob/main/Read_messages_from_telegram.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# !pip install telethon
# Out:
# Collecting telethon
#   Downloading Telethon-1.24.0-py3-none-any.whl (528 kB)
#      |████████████████████████████████| 528 kB 5.0 MB/s
# Collecting pyaes
#   Downloading pyaes-1.6.1.tar.gz (28 kB)
# Requirement already satisfied: rsa in /usr/local/lib/python3.7/dist-packages (from telethon) (4.8)
# Requirement already satisfied: pyasn1>=0.1.3 in /usr/local/lib/python3.7/dist-packages (from rsa->telethon) (0.4.8)
# Building wheels for collected packages: pyaes
#   Building wheel for pyaes (setup.py) ... done
#   Created wheel for pyaes: filename=pyaes-1.6.1-py3-none-any.whl size=26363 sha256=77c8a20d4e72e8f8c9d532554d01f77a6ca76dc32c72cec7ffd13cbd6e2df094
#   Stored in directory: /root/.cache/pip/wheels/42/a3/7d/73d60820adb58d818179cdec3fc1be66f6f7453513a3ff0b05
# Successfully built pyaes
# Installing collected packages: pyaes, telethon
# Successfully installed pyaes-1.6.1 telethon-1.24.0

# %%
import pandas as pd
import telethon
from telethon.sync import TelegramClient
import datetime
from telethon import TelegramClient, events, sync
import asyncio

# %%
api_id = '' 
api_hash = ''

# %%
import nest_asyncio
nest_asyncio.apply()

# %%
async def main():
  client = TelegramClient('session_name', api_id, api_hash)
  await client.start()
  channel = await client.get_entity('equity99')
  messages = await client.get_messages(channel, limit= 100)
  for x in messages:
        print(x.text) #return message.text

asyncio.run(main())
# Out:
# Market volatility to continue: Rahul Sharma, Equity 99
# We witnessed bloodbath in markets with market correcting almost 3% driven by continuous FII selling and high uncertainty in the market ahead of US Fed meeting. US markets, crypto, Indian markets all are falling as FED is taking out the money. The clarity would be only after the FOMC meeting on Wednesday. However, this fall is a good opportunity for adding quality stocks. We expect the volatility to continue in the market for a short run.
#
# https://economictimes.indiatimes.com/sensex-nifty-live-today-2022-01-24/liveblog/89083144.cms
#
# __**Best Ev Play
#
# Rasandik Engg Bse Code 522207 Cmp 173.60 ( Only Bse Listed )
#
# Test Levels 239 / 260 Sl 150 Coming Days view Short Term View__**
# Rasandik Engg Standalone September 2021 Net Sales at Rs 52.42 crore, up 57.09% Y-o-Y
#
# https://www.moneycontrol.com/news/business/earnings/rasandik-engg-standalone-september-2021-net-sales-at-rs-52-42-crore-up-57-09-y-o-y-7738741.html
# https://m.economictimes.com/markets/stocks/recos/buy-bcl-industries-target-price-rs-960-equity99/articleshow/89087019.cms
# Ready To Break Above 111🚀🚀
# **Volume break out in negative market on daily chart of GSTL.
#
# Look @ DAILY chart of GSTL. stock has given broken intermediate top with record volumes. Volumes confirms uptrend in this counter. Now above 111 expect 127----140 levels fast**
# *Solid Note*
#
# GLOBALSPACE TECHNOLOGIES (GSTL) is a New Age ICT company providing cutting edge enterprise mobility solutions and Digital Consulting.
#
# The company has created MediApp which provides B2B platform to retail chemists, stockists and pharma companies offering at present 22000 products, more than 11 companies and functional in 15 states.
#
# It has another platform Docexa using AI which is said to be India’s first virtual clinic platform where doctors can connect with patients directly.
# __**Small IT Stock Looking Good ( High Conviction )
#
# Global Space Technology ( GSTL ) BSE CODE 540654
#
# Test Levels 130 / 150 Long Term 250 Sl 65
#
# Coming Days view Strong Potential View / Short Term View / Long Term View__**
# Good Levels To Average any time Circuit Open
# **Ethanol Big Play**
#
# **BCL INDUSTRIES CMP 441.20**
#
# Possible Lower Circuit Open Once Market Stable
#
# #Turnaround candidate from buzzing sector
# Driven by the current drive in ethanol sector BCL Industries country's 2nd largest grain based ethanol producer is incurring capex to increase its existing capacity by 200 KLPD. Company has already incurred Rs 18cr in FY21. Post capex we expect this counter to give good returns.
# **Long term trend line break out on weekly chart of AJMERA REALTY.
#
# Look @ weekly chart of AJMERA REALTY. stock has broken long term resistance trend line which is highly bullish sign. Now above 450 expect 485---500 levels fast**
# **Ready To Break Above 450🚀**
# __**Today We Share Best And Fundamental Strong Reality High Conviction Stock __**
#
# **Best Research 2022🚀** **Protfolio Multiple__
#
# Ajmera Realty Cmp 445 / 455
#
# Test Levels 1000 Long Term Sl 310
#
# Coming Days view 550 Expected upper Circuit Candidate**__
# **Morning Alert..
#
# *SEBI likely to issue consultation paper on rating of ESGs***
# The SEBI has started work on having standardized norms for companies on the environment, social and governance factors, a move to guide investors take better investment decisions. Two people with knowledge of the matter said, requiring anonymity, that the markets regulator is expected to soon issue a discussion paper outlining regulatory and supervisory approaches for ESG ratings.
#
# ***PNB looks to sell stake in NCDEX, Pridhvi ARC***
# Punjab National Bank is looking to sell its stake in Pridhvi Asset Reconstruction and Securitisation Co. Ltd and Commodity and Derivative Exchange NCDEX to free up capital to expand leading and invest in the so-called bad bank.
#
# ***India biggest exporter of gherkins as shipments cross $200 Mn in FY21***
# India has become the largest exporter of gherkins-baby cucumbers typically used for pickling- with the shipments crossing $200 Mn in FY21, the commerce and industry ministry said. India shipped over 2.23Tn tonnes of cucumber and gherkins, also known as cornichons, the ministry added.
#
# ***Commodity play***
# Gold – Rs 48494/10gm, Silver – Rs 64656/kg, Brcrude – Rs 6584/Barrel, Degumsyoil – Rs 1174/10kg, Copper – Rs 759/kg.
#
# ***Corporate news***
# Future Retail – Amazon says Samara capital ready to invest Rs 70Bn in Future Retail.
#
# Prakash Industries – Co has secured long term coal linkages of 1,95,900 MT per annum for next 5 years in the coal linkage auction concluded by Coal India.
#
# ICICI Bank – Co reported PAT 62Bn vs 49.4Bn (YoY), 55Bn (QoQ); Interest earned 221 Bn vs 197 Bn (YoY).
#
# **Sector in focus - Banks, Automobiles, Chemicals & Realty.**
#  Rahul Sharma, co-owner, Equity 99, said: “Zomato’s fall comes days after Paytm crashing to its historic low. We see this as a good opportunity for long-term investors to add these counters at considerable discount as they might be reporting losses now but has huge growth potential considering their business models.”
#
# https://www.business-standard.com/article/markets/zomato-hits-record-low-market-capitalisation-falls-below-rs-1-trillion-122012200014_1.html
# Hit High 129.45🚀🚀
# **Huge Volume Consolidation
#
# Technical Break Above 130 To 135 Expected Sharp Upside
#
# After 15 Stock Move higher Levels
#
# TTL CMP 128
#
# TEST LEVELS 160 SL 105
#
# COMING DAYS VIEW STRONG VIEW**
# **Ready To Cross Above 500 Levels **Once Market Stable🚀
# ***Small Sweet Note*
#
# *Ethanol Story Can Be Game Changer***
#
# *BCL Industries Ltd* Limited is a part of Mittal group. The company is in the edible oil and distillery business in India. Company has good ROCE of 17.2% and ROE of 17.8%. Despite giving such good returns in short term company is still undervalued and is available at PE of just 17.6x against industry PE of 49.6x. Company is big beneficiary of ethanol play and we expect it to give multibagger returns in short period of time.
# **Lower Circuit Open Hit High 486 From Lower Circuit 462.65🚀**
# **Big rounding bottom break out on weekly chart of TT LTD.
#
# 10 Years Bullish Multiyear Breakout above 135🚀
#
# Look @ weekly chart of TT LTD. stock has given multi year rounding bottom formation. Now expect 145----150 levels fast**
# **Fundamental view
#
# T T Limited is engaged in manufacturing of yarn, fabric, garments and other textile products. The Co has two Spinning Mills, two Knitting Factories and multiple Garment Manufacturing
# Units all across India. The current installed capacity stands at 10,400 TPA for yarn division and 3,400 TPA for fabric division. Company is also undertaking capex.
#
# It derives 54% of its revenue from exports.
#
# Company has superb ROE of 26%. Company trades at PE of just 7.08x against Industry PE of 31.3x. Huge upside potential considering the current boom in textile sector. Stock is available at Mcap of just 244Cr against EV of 478Cr. It has delivered PAT growth of 92.62% CAGR over last 5 years. Promoters are majority shareholders holding 58.17% shares and have increased their shareholding in Sep 21 Qtr.
#
# We are highly bullish on this counter and expect it to give quick returns considering the way textile sector is booming.**
# Ready To Open Lower🚀
# **Due To Continuously Pressure In Market Some Stock Available @ Lower Levels
#
# Attractive Stock From Lower Levels
#
# Expected Any Time Lower Open Keep Accumulate🚀
#
# BCL IND Cmp 462.65
#
# Test Levels 650 Sl 380
#
# Coming Days view Strong Potential View**
# __**Due To Continuously Pressure In Market Some Stock Available @ Lower Levels
#
# Attractive Stock From Lower Levels **
#
# Hubtown Cmp 63
#
# Test Levels 75 / 95 Sl 48
#
# Coming Days view Strong Potential View__
# **🥁🥁  Available Finance  🥁🥁
#
# This stock was recommended on 19th January @115
#
# Today it now locked at upper circuit @132.30
#
# Gaining 15 % in just 2 days.
#
# Superb Performance 🚀🚀🚀🚀
#
# 🥁🥁🥁🥁🥁🥁🥁🥁🥁🥁🥁**
# **Morning Alert…**
#
# **Stocks dive for 3rd day on global cues**
# Indian stock fell for the third straight day, setting the benchmark indices on course for their worst weekly performance in more than a month, as soaring crude oil prices and fear of a US interest rate hike weighed on investor sentiment. On Thursday the benchmark indices slid more than 1% and is down approx. 3 % for this week.
#
# **Former CAG Vinod Rai joins Unity SFB as independent chairman**
# RBI has approved the appointment of former comptroller and auditor general Vinod Rai as independent chairman of Unity Small Finance Bank. Rai, a former chairman of Banks Board Bureau, has also served in the ministries of finance, commerce and defence.
#
# **No tax breaks for Tesla without make-in-India commitment**
# Talks between the government and Tesla Inc. over potential tax benefits are deadlocked as the government is not keen to give the company any breaks without a commitment to manufacture locally, people familiar with the discussion said.
#
# **Commodity play:**
# Gold – Rs 48532/10gm, Silver – Rs 6424/kg, Brcrude – Rs 6645/Barrel, Degumsyoil – Rs 1164/10kg, Copper – Rs 758/kg.
#
# **Corporate News:**
#
# **Future Retail** – Company may not be able to meet Rs 3500 Crore debt deadline.
#
# **PTC India** – Regulator to seek company`s reply on exit of directors.
#
# **Indotech Transformers** – Dolly Khanna bought 1.15% stake in Company.
#
# **Sector in focus - Banks, Entertainment, Automobiles & Telecommunications.**
# Rahul Sharma, Co-owner, Equity 99 said, "The volatility in the market due to the weekly expiry and heavy weights like Reliance and IT stocks dragged the market down, despite the rise in Asian peers. We expect market to see a upward movement in Friday's trade. Investors are advised to take advantage of such downfalls to accumulate quality stocks on major dips. There will be volatility in the market till the budget.
#
# https://www.businesstoday.in/markets/stocks/story/sensex-tumbles-1844-points-three-sessions-nifty-crash-market-cap-falls-319766-2022-01-20
# **🥁🥁🥁        C C D      🥁🥁🥁
#
# Coffee Day Enterprise Ltd
# 🚀🚀
# December Month Performer
# 🚀🚀
#
# Stock was recommended on 23rd December @ 45.50
#
# Today after few days the stock is trading high up levels and now locked at Upper Circuit @ 80.40
#
# All test levels achieved ✅
#
# Almost Gaining 77 % in short duration
#
# 🚀🚀🥁🥁💥💥⚡️⚡️⚡️💥💥**
# https://hindi.moneycontrol.com/news/markets/hotstocks/booking-of-profits-is-possible-in-the-market-before-the-budget-these-5-favorite-stocks-of-rahul-sharma-of-equity99-which-will-earn-huge-in-the-short-term-404841.html/amp
# Hit High of 75 🚀🚀
# https://www.thehindubusinessline.com/companies/orient/article64906280.ece/amp/
# __**Midday Pick
#
# SPLIL ( SPL IND ) CMP 71
#
# TEST LEVELS 90 SL 50
#
# COMING DAYS VIEW STRONG VIEW__**
# SHRIRAM EPC offers services relating to industrial processes, metallurgy, thermal power plants, biomass power plants, Mines and Mineral processing, water and waste and water management and distribution systems.
#
# Government may allocate strong orders in the water and waste water management segment which is beneficiary for companies like SHRIRAM EPC.
#
# Before budget infrastructure related stocks showing strong strength and this company may turn around in coming time so strong fancy may emerge in this counter.
# **Rounding bottom break out in weekly chart of SHRIRAM EPC
#
# Look @ weekly chart of SHRIRAM EPC. STOCK has given rounding bottom break out. Now expect rally upto 17---20 levels in coming days**
# **Special Situations Stock ( High Conviction )
#
# SHRIRAM EPC Cmp 10.5 / 10.65
#
# Test Levels 17 / 20 Sl 7
#
# Coming Days view / Short Term View**
# **🥁🥁  Available Finance  🥁🥁
#
# This stock was recommended yesterday @115
#
# Today it now locked at upper circuit @126
#
# Gaining 10% in just BTST
#
# Superb Performance 🚀🚀🚀🚀
#
# 🥁🥁🥁🥁🥁🥁🥁🥁🥁🥁🥁**
# **Ethanol Story Game Changer ( Potential Next Level Multibagger )
#
# *BCL Industries Ltd Cmp 500*
#
#  - *The Big Ethanol Story*
# *Fundamentals*
# ROE ~17.8%
# ROCE ~17%
# Promoter Holding - 61.36%
#
#  BCL Industries is a diversified business house with business interest spread across the variety of industries namely Edible Oil & Vanaspati, Distilleries & Real Estate.
#  BCL is one of the largest edible oil complex in North India having a capacity 1,020 tons per day. It has integrated edible oil plant with the ability to conduct processing of oilseeds as well as packaging 8 brands of refined edible oil.
#  BCL is also one of the largest grain-based Ethanol manufacturers in the country
#  Company has monetized its Real Estate projects and proceeds are to be utilised for repayment of company’s debt
#
# *Recent Developments*
#  Co has won an order from OMCs to supply 4.1cr litres of Ethanol from 1st Dec'21 to 30th Nov'22.
#  The per unit rate of Ethanol made from the Damaged Food Grains has been increased by Rs. 1.37 per ltr to Rs. 52.92 per ltr now
#  The co has performed the groundbreaking ceremony (Bhoomi Pujan) of its brownfield distillery plant expansion in Bathinda, Punjab on 7/12/2021 for setting up another state-of-the-art plant having an installed production capacity of 200KLPD of Ethanol & 10 MW of power co-generation.
#  Capacity of Bathinda unit to increase from 200KLPD to 400KLPD post expansion.  Plant likely to be commissioned by Nov'22 & likely to be one of the largest plants in the entire country grain-based distillery.
# * According to the government guidelines in the National Biofuel Policy for blending Ethanol, the target is to reach a 20% blending rate by 2023.*
#
#  *Co has reported lifetime best quarterly performance in Q2FY22 and we expect the streak to continue in Q3*
# ~ Revenue at 462cr vs 449cr (+3% QoQ) vs 325cr (+43% YoY)
# ~EBITDA at 37cr vs 31cr (+20% QoQ) vs 25cr (+48% YoY)
# ~PAT at 21cr vs 17cr (+24% QoQ) vs 12cr (+78% YoY)
# ~EPS of 8.66 vs 7 (+24% QoQ) vs 5.25 (+65% YoY)
#
# We are highly bullish on this counter considering the increasing demand for Ethanol and company`s future plans. From current levels company is capable of giving quick returns. We recomment buying in this counter with Target price of *650 / 700 / 900 / 950* and Stop loss of *260*.**
# **Strictly For Long Term
#
# SPLIL ( SPL IND ) Cmp 71
#
# Test Levels 120 Sl 45**
# __**Again Circuit Open🚀
#
# Circuit 2 Circuit Candidate ( Best Ethanol Play )
#
# Next Like Globus Spirit
#
# BCL IND Cmp Range 500
#
# Test Levels 650 / 750 / 960 / 950 Sl 260
#
# Coming Days view / Short Term View / Long term View__**
# **Morning Alert..**
#
# **US yield surge keeps indices in the red**
# The benchmark indices on Wednesday declined for about 1% for the second day in a row amid risk aversion triggered by the spike in US bond yields, which investors see as a precursor to the end of the easy money regime. The 10-year US treasury inches towards 1.9% overnight.
#
# **Overseas investment cap for MFs may be doubled**
# The SEBI is considering doubling the overseas investment limit for domestic mutual funds, a move that will help citizens diversify their investments. According to sources the market regulator intends to increase the industry-wide limit from $7 bn to $12 bn or $15 bn.
#
# **Microsoft, Telangana seal deal for Rs 15000Cr data centre in Hyderabad**
# US tech giant Microsoft and the Telangana government have finalised a deal to set up a Rs 15000 Cr data centre in Hyderabad. A 50-acre land near the city is believed to have been finalized and the project is expected to create around 300 jobs. According to sources aware of the development, a formal announcement is likely to come within a month.
#
# **Commodity play**
# Gold – Rs 48064/10gm, Silver – Rs 63301/kg, Brcrude – Rs 6649/Barrel, Degumsyoil – Rs 1154/10kg, Copper – Rs 749/kg.
#
# **Corporate News**
# **RIL** – Jio clears pre-2021 spectrum dues.
#
# **LTI** – Q3 PAT 6.1Bn vs 5.2Bn (YoY), Est 5.9Bn; Q3 revenue 41.4Bn vs 31.5Bn (YoY).
#
# **Tata Communications **– Q3 PAT 3.9Bn vs 3.1Bn (YoY), Est – 4Bn, Q3 revenue 41.84Bn vs 42Bn (YoY).
#
# **Sector in focus - Finance, Pharma, Chemicals & Consumer durables.**
# Outlook for January 20
#
# Rahul Sharma, Co-owner, Equity 99
#
# The correction in markets continued for the second day as markets correct a percent after US bond yields hit a two-year high. We see weakness in the market for the coming two weeks.
#
# Investors are advised to keep strict stop losses and adopt buy-on-dips strategy. We expect the volatility to continue till the budget session. It is advised not to overtrade in the current scenario.
#
# For the Nifty, 17,880 will act as immediate support, a break could see the index slipping to 17,765. On the upper side, 17,980 will act as strong resistance. Once the index goes past this level, it may move towards 18,075 and even 18,200.
#
# https://www.moneycontrol.com/news/business/markets/taking-stock-market-ends-lower-for-the-second-day-sensex-dives-656-points-nifty-below-18000-7958371.html
# "The correction in markets continues for the second day as markets correct 1 per cent post-US bond yield hitting a 2-year high. We see weakness in the market for the coming two weeks. Investors are advised to keep strict stop losses and adopt buy on dips strategy. We expect the volatility to continue till the Budget session. It is advised not to overtrade in the current scenario," said Rahul Sharma, Co-owner, Equity 99.
#
# https://www.ndtv.com/business/share-market-live-updates-sensex-dives-656-points-led-by-sell-off-in-it-stocks-nifty-settles-below-17-950-2717113
# **🥁🥁🥁 ONMOBILE 🥁🥁🥁
#
# The Stock has shown tremendous Performance
#
# It was recommended on 28th December @ 102 with High Conviction.
#
# Today it made fresh high 154.60 at Upper Circuit 🚀
#
# Gaining almost 52% return in less than one month
#
# 🚀🚀🚀🚀🚀🚀🚀🚀🚀🚀**
# **🥁🥁🥁 BCL IND 🥁🥁🥁
#
# Upper Circuit Hit 🚀🚀🚀
#
# Even when market is showing such weakness, our conviction stock is performing like a super star 🌟💫**
# **Ready To Hit Again Upper Circuit🚀**
# __**BTST STRONG
#
# BCL IND CMP 478.10
#
# TEST LEVELS 490 SL 465__**
# **🥁🥁 PFS 🥁🥁
#
# This stock was recommended yesterday @23.50 with conviction of moves above 24.25
#
# The stock has made high of 25.05 in this week market 🚀🚀🚀🚀🚀**
# **🥁🥁 BCL Industry Ltd 🥁🥁
#
# In this weak market look at performace of BCL Industry
#
# Yesterday recommended at 461
#
# Today traded high at got locked at Upper Circuit Levels @ 478 .10
#
# 🚀🚀🥁🥁🚀🚀🥁🥁🚀🚀🥁🥁**
# Ready To hit 112🚀🚀
# **Special Situations Stock ( Very High Conviction )
#
# Menon Bearing Cmp 109
#
# Test Levels 150 / 170 Sl 85
#
# Coming Days view Strong Potential View**
# **Strong break out weekly chart of SHALIMAR PAINTS.
#
# Look @ weekly chart of SHALIMAR PAINTS. Stock has given inverse head & shoulder pattern break out. Now it is ready to kiss 155---165 levels fast**
# https://www.moneycontrol.com/news/business/infra-market-set-to-invest-rs-270-crore-in-shalimar-paints-7954201.html
# __**Special Situations Stock ( High Conviction )
#
# Shalimar Paints Cmp 143
#
# Test Levels 175 / 196 Sl 120
#
# Coming Days view / Short Term View__**
# Ready To hit upper 120🚀
# __**Important Stock
#
# Available Finance Bse 531310 Cmp 115 / 120
#
# Book Value 472 Trade @115 / 120
#
# Potential Upper Candidate__**
# https://www.indiainfoline.com/article/news-top-story/welspun-india-enters-the-dow-jones-sustainability-world-index-scoring-62-higher-than-the-average-industry-score-121121600296_1.html
# Welspun special
#
# Huge Volume Consolidation Between 25
#
# Once Break Above 26 Hurdle Circuit Candidate🚀
# **Near to break Above 26**
# **Cup & handle formation break out on weekly chart of WELSPUN SPE SOLUTION.
#
# Break above 26 Highly life Time Bullish Break Out
#
# Look @ weekly chart of WELSPUN SPE SOLUTION. Stock has given multi year cup & handle pattern break out which is bullish sign. Now above 26 expect non stop rally upto 30---33 levels**
# **Tiny Multibagger Research ( First Time )
#
# Welspun Specialty Solutions Bse code 500365 Cmp 25
#
#  Welspun Specialty Solutions is engaged in the business of manufacturing alloy, stainless steel & its products. Company is trying to move from low margin alloy steel making to high margin SS products. With the successful commissioning and stabilization of Stainless Steel pipes & tubes facility, the company has decided to focus on high-value and niche sector. Considering the turnaround in company`s business we expect huge upside in this counter.**
# Ready To Break Above 26🚀
# **Special Situations Stock ( High Conviction )
#
# Welspun Sol ( Only Bse Listed Stock ) Bse Code : 500365** Cmp **24.50 / 25**
#
# Test Levels 30 / 36 / 42 Sl Long Term 60 / 70 Sl 17
#
# **Coming Days view Strong Potential View ( 20 % Upper Candidate Single day / Coming Days )**
# **Morning Alert..**
#
# **Centre may offer tax sops to home buyers**
# Finance minister may propose higher tax deduction on home loans in the budget to boost housing demand, two officials familiar with the development said. The government is considering increasing the annual tax deduction limit for repayment of housing loan principal under Section 80C to Rs 2 lakhs from the current cap of Rs 1.5 lakhs. The official said that this move is being contemplated to provide relief to taxpayers and boost real estate demand.
#
# **Railways likely to get a booster shot in Union Budget**
# The budget allocation for railways is set to hit record level next fiscal as the government gears up to support major makeover for the national transporter. Budget 2022-23 is likely to raise plan size for Indian Railways by up to 20% of FY22 budget estimates, which would take up its allocation to close to Rs 2.5Tn.
#
# **Centre to use SC order to counter Devas**` arbitration in foreign courts
# Finance Minister
# Nirmala Sitharaman said the Narendra Modi administration would contest multiple arbitration awards won by shareholders of Devas Multimedia over a cancelled contract on the strength of the Supreme Court`s validation of the fraud charges against the company.
#
# **Commodity play**
# Gold – Rs 47940/10gm, Silver – Rs 61374/kg, Brcrude – Rs 6565/Barrel, Degumsyoil – Rs 1141/10kg, Copper – Rs 746/kg
#
# **Corporate News**
# Zeel – Axis Bank arm threatens action against Zee promoters over dues.
#
# Just Dial – Q3 PAT 194MN vs 499Mn (YoY), Est 480Mn, Revenue 1.59Bn vs 1.7Bn (YoY).
#
# ICICI Prudential – Q3 PAT 3.11Bn vs 3.06Bn (YoY); Est 3Bn, Revenue 90.74Bn vs 89.71Bn (YoY).
#
# **Sector in focus - Banks, Metals, Real-estate & Sugar.**
# https://www.livemint.com/market/stock-market-news/5-stocks-to-buy-for-short-term-from-rahul-sharma-of-equity99-11642501932026.html
# How to navigate this market?
# Market corrected today by almost 1%. The correction might continue for some time now with minor profit booking seen with Budget nearing. Investors should take advantage of this fall to add quality counters on major dips.
#
# -- Rahul Sharma - co-owner, Equity 99
#
# https://economictimes.indiatimes.com/sensex-nifty-live-today-2022-01-18/liveblog/88963178.cms
# 💥💥💥Palred Tech 💥💥💥
#
# This stock information was provided on our Mobile Application in September month @ 134, Recently the stock has made high of   252.75 i.e. almost 100% gains in short term.
#
# Such High Conviction Stocks are shared on our Mobile Application, so
# If you want to know more of these fantastic recommendations.
#
# Download our Mobile Application Now.
#
# https://play.google.com/store/apps/details?id=io.equity99.equity99app
# https://www.business-standard.com/article/news-cm/bcl-industries-jumps-on-order-win-121120600293_1.html
# **Can be Hit Again Upper Circuit🚀**
# __**Again Circuit Open🚀
#
# Circuit 2 Circuit Candidate ( Best Ethanol Play )
#
# Next Like Globus Spirit
#
# BCL IND Cmp Range 461.05
#
# Test Levels 600 / 700 / 900 / 950 Sl 260
#
# Coming Days view / Short Term View / Long term View__**
# Multi year break out in PFS.
#
# Look @ weekly chart of PFS. Stock has given multi year break out after 2018. Now above 24.25 expect 27.3---30 levels in coming days
# https://www.indiainfoline.com/article/news-top-story/bcl-industries-hits-new-high-on-business-update-of-ethanol-plant-122011100491_1.html
# Rahul Sharma, Co-owner, Equity 99 | In coming days, we expect movement in markets to be sector specific. However Midcap and Smallcap space will show good move in coming days. Overall, the market outlook looks positive and one should look to keep add quality stocks in their portfolio. Traders should trade into sector specific stocks, keep booking their profit and trail strict stop loss. For Nifty 18200 will act as very crucial support on breaking which we might see 18120 levels. On upper side 18300 will act as crucial hurdle, if this level is breached, we might see 18370 levels and then even 18480 looks possible.
#
# https://www.moneycontrol.com/news/photos/business/markets/slideshow-market-likely-to-consolidate-further-with-nifty-facing-resistance-at-18400-experts-7944171-6.html
# ***Small & Sweet Note***
#
# **Can Be Next MultiFold 3 x **
#
# **BCL IND Cmp 461.05 ( NEAR UPPER CIRCUIT )**
#
# **BCL Industries Ltd** is a diversified conglomerate in manufacturing and development with business interests spread across a variety of industry verticals namely Edible Oil and Vanaspati, Distillery, Ethanol and Real Estate.
# In the distillery segment it is engaged in the business of manufacturing of Ethanol, Extra Neutral Alcohol (ENA) and bottling of liquor in Punjab.
# BCL Industries Ltd continues to be one of the largest suppliers of Grain Based Ethanol in the nation with a tender to supply 4.5 crore liters of ethanol in the sugar year 2020-21.
# The company is experiencing strong demand for both ENA and Ethanol and subsequently improved margins due to an increase in the prices of DDGS and ENA.
# Two years ago GLOBUS SPIRIT was trading around 150 levels and now it is trading around 1650 levels. Same kind of big momentum expected in BCL Industries from here in the longer term.
# Multi year trend line break out on monthly chart of BCL IND.
#
# Ready To Hit Upper Circuit🚀
#
# Look @ monthly chart of BCL IND. stock has given multi year trend line break out. Now it is trading in blue sky zone & expect more upside levels from here after multi year break out. Expect 550---600 levels in medium term
# **Ready To Hit Upper Circuit🚀 461.05**
# __**Circuit 2 Circuit Candidate ( Best Ethanol Play )
#
# Next Like Globus Spirit
#
# BCL IND Cmp Range 450 / 461.05**
#
# Test Levels 600 / 700 / 900 / 950 Sl 260
#
# Coming Days view / Short Term View / Long term View__
# **As the ETHONAL is in flavour of the current market, soon after few minutes we will provide one fantastic research which has potential same as 💥 Globus Spirit which performed from 200 levels to 1760 levels. 💥
#
# Stay Tuned with us.**
# **🥁🥁🥁AYM SYNTEX 🥁🥁🥁
#
# Stock which we recommended in Morning Buzzing Research @ 147
#
# Has made fresh high of 158.35
#
# 🚀🚀🚀🚀🚀🚀🚀🚀🚀🚀**
# Hit High Of 156.50 🚀
# Huge Volume Consolidation Break Out Trend channel Above 155🚀
# Ready To Bounce back Towards New High 🚀🚀
# AYM Syntex Standalone June 2021 Net Sales at Rs 305.96 crore, up 235.67% Y-o-Y
#
# https://www.moneycontrol.com/news/business/earnings/aym-syntex-standalone-june-2021-net-sales-at-rs-305-96-crore-up-235-67-y-o-y-7265851.html
# AYM SYNTEX. Ready for long term rounding bottom break out.
#
# Important Resistance 155 As A Big Break Out
#
# Look @ weekly chart of AYM SYNTEX. Stock is ready to give rounding bottom break out. After this break out stock will enter into blue sky zone. Expect 175---180 levels in this counter
# __**Morning Buzzing Research ( High Conviction )
#
# Aym Syntex Range 147 / 150
#
# Test Levels 180 / 195 Sl 120
#
# Coming Days view Strong Potential View__**
# Flag pattern break out on daily chart of BRIGADE ENTER.
#
# Look @ daily chart of BRIGADE ENTER. Stock has given flag pattern break out. Now above 525 expect 575---600 levels
# **🥁🥁🥁 Shalimar Paints 🥁🥁🥁
#
# This stock was recommended on 13Jan with High Conviction @ 128
#
# Stock has been showing good performance, today trading high at 142.25
#
# Making easy 12% gains
#
# 🚀🚀🚀🚀🚀🚀🚀🚀🚀🚀🚀**
# **🥁🥁🥁 AKSH OPTI 🥁🥁🥁
#
# This stock has been recommended on 13th January with conviction @ 13.70
#
# Just 3 session the stock has made high of 15.80
#
# Making return of 15% in just 3 days 🚀🚀🚀🚀🚀🚀🚀🚀🚀🚀**
# **Morning Alert..**
#
# **Bond yield hit 2 year high; Brent near $86**
# Bond Yield hit a 2 year high, tracking an uptick in US yields and a continued rise in global crude oil prices which has raised expectations of rate increases by the RBI. US treasury yields rose on Friday and stayed higher in Asia trade as a batch of soft consumer and manufacturing activity data were seen as not enough to derail the Federal Reserve`s path of tightening policy.
#
# TRAI to review auction payment terms
# The telecom regulatory Authority of India (TRAI) will decide whether operators would get a four-year moratorium or longer after upfront payment of fresh spectrum they acquire in the 5G auctions to be held later this year, or the two year moratorium, which has been the past practice which would continue. TRAI will also decide if operators need to pay any upfront amount or the same would be waved this time.
#
# PM asks glob firms to invest in India
#
# PM Modi pitched India as an attractive investment destination, calling on global firms to take advantage of a raft to reforms undertaken by his government in critical areas ranging from corporate taxation to reduction in corporate compliance burden. He was delivering a special address at the World Economic Forum`s Devos Agenda through video conference.
#
# **Commodity play**
# Gold – Rs 47997/10gm, Silver – Rs 61550/kg, Brcrude – Rs 6473/Barrel, Degumsyoil – Rs 1140/10kg, Copper – Rs 748/kg.
#
# **Corporate news**
# Tech Mahindra – Co approved proposal for acquisition of 100% stake in Com Tec Co IT Ltd.
#
# HFCL – Q3 PAT 783.8Mn vs 822.4Mn (YoY); 816Mn (QoQ), Q3 revenue 12.15Bn vs 12.77Bn (YoY).
#
# Angel One – Q3 PAT 1.65Bn vs 732Mn (YoY); Est 1.5Bn, Q3 Revenue 5.97Bn vs 3.07Bn (YoY).
#
# **Sector in focus - Banks, Automobiles, Finance & Metals.**
# Important Alert 🚦🚦🚦
#
# On 7th January  we have recommended CMS INFO on Equity99 Mobile Application @ 240 with High Conviction. 🥁
#
# Today after 10 Days the stock is trading high at 317.45🚀
#
# Gaining 32 % in Just 10 Days. ✅
#
# Such High Conviction Stocks are shared on our Mobile Application, so
# If you want to know more of these fantastic recommendations.
#
# Download our Mobile Application Now.
#
# https://play.google.com/store/apps/details?id=io.equity99.equity99app
# Broader rally
#
# Rahul Sharma, Co-owner, Equity 99, said: The winning streak in the market came to a halt on Friday. However, we saw some buying in quality counters in the small-cap space. In the coming days, we expect sector specific movement in the markets. However the midcap and smallcap space will show a good move in the coming days. Overall, the market outlook looks positive and one should look to keep adding quality stocks in their portfolio. "
#
# https://www.thehindubusinessline.com/markets/market-is-likely-to-see-a-gap-down-opening/article64905348.ece
# **🥁🥁🥁 JSW ISPAT 🥁🥁🥁
#
# The stock was recommended at 39.25 - 39.50 today.
#
# It has made high of 43.80🌈
#
# This is good 9% move in Intraday itself 🚀🚀🚀🚀🚀🚀🚀**
#
# More to Go 💥💥⚡️⚡️
#
# 🥁🥁🥁🥁🥁🥁🥁🥁🥁🥁
#
# **Hello Members,
#
# This is for your information & knowledge:
#
# Recently Recommended Fundamental Research Stock Report which was provided at very economical cost, has given tremendous returns to our dear investors, the stock has performed so well that it gave return of approx 50% in less than 40 days.
#
# We are soon planning similar kind of  Fundamental Exclusive Research Report which will be available at exclusive price of 599 only.
#
# Give us your feedback in below poll.
#
# Best Regards
# Equity99**
# **JSW Ispat Special Products Ltd is engaged in manufacturing and marketing of sponge iron, steel and ferro alloys, along with billets and pellets. Presently, the company owns and operates 2 steel plants in Raigarh and Raipur in Chattisgarh with capacity of 0.95 MMTPA and 0.24 MMTPA respectively.[4] It also has captive power generation capacity of 234 MW.
#
# Synergies with New promoter post corporate Insolvency
# The Company enjoys synergies with JSW Steel that provides it raw material and offtake security. JSW Steel has 13 fully operational captive mines in Karnataka and Odisha providing raw material assurance. It is also planning to enter into a coke conversion agreement with Bhushan Power and Steel Limited i.e. a group company. [2] JSW Steel only holds ~23% stake of the company on a consolidated level.
#
# Stock is available at Mcap of just 1845Cr against Enterprise value of 4562Cr. Almost 3x possible from current valuations. Company has reported positive operational flows after 4 years.**
# **Hit High 41.45 From 39.50🌈**
# **🥁🥁🥁        C C D      🥁🥁🥁
#
# Coffee Day Enterprise Ltd
# 🚀🚀
# December Month Performer
# 🚀🚀
#
# Stock was recommended on 23rd December @ 45.50
#
# Today after few days the stock is trading high up levels at 71.80
#
# All test levels achieved ✅
#
# Almost Gaining 58 % in short duration
#
# 🚀🚀🥁🥁💥💥⚡️⚡️⚡️💥💥**
# Range break out on weekly chart of JSW ISPAT.
#
# Look @ weekly chart of JSW ISPAT. Stock has given range break out. Now above 41 expect sharp rally upto 46---50 levels
# __**Special Situations Stock ( High Conviction )
#
# Jsw Ispat Special Products ( Jswispl ) Cmp 39.50 / 40
#
# Test Levels 50 / 55 / 59 Sl 30
#
# Coming Days view Very Strong Potential View__**
